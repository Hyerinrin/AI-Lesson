# %% [markdown]
# <a href="https://colab.research.google.com/github/Hyerinrin/AI-Lesson/blob/main/%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5_9%EC%A3%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

#데이터 읽어와서 신경망에 입력할 형태로 변환
(x_train,y_train),(x_test, y_test)=fashion_mnist.load_data()

#class name
class_names=['T-shirt/top','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']

#
print(x_train.shape)

#data display
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i],cmap=plt.cm.binary)
    plt.xlabel(class_names[y_train[i]])
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step
# (60000, 28, 28)

# %%
x_train=x_train.reshape(60000,784)
x_test = x_test.reshape(10000,784)
x_train=x_train.astype(np.float32)/255.0
x_test=x_test.astype(np.float32)/255.0
y_train=tf.keras.utils.to_categorical(y_train,10)
y_test=tf.keras.utils.to_categorical(y_test,10)

n_input=784
n_hidden=1024
n_output=10

mlp=Sequential()
mlp.add(Dense(units=n_hidden,activation='tanh',input_shape=(n_input,)
             ,kernel_initializer='random_uniform',bias_initializer='zeros'))
mlp.add(Dense(units=n_output,activation='tanh'
             ,kernel_initializer='random_uniform',bias_initializer='zeros'))

mlp.compile(loss='mean_squared_error',optimizer=Adam(learning_rate=0.001),metrics=['accuracy'])
hist=mlp.fit(x_train,y_train,batch_size=128,epochs=30,validation_data=(x_test,y_test),verbose=2)

res=mlp.evaluate(x_test,y_test,verbose=0)
print("정확률은",res[1]*100)
import matplotlib.pyplot as plt

#정확도 곡선
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'],loc='upper left')
plt.grid()
plt.show()

#손실함수 곡선
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'],loc='upper right')
plt.grid()
plt.show()
# Out:
# Epoch 1/30
# 469/469 - 7s - loss: 0.1179 - accuracy: 0.2867 - val_loss: 0.0351 - val_accuracy: 0.8115 - 7s/epoch - 15ms/step
# Epoch 2/30
# 469/469 - 1s - loss: 0.0304 - accuracy: 0.8442 - val_loss: 0.0285 - val_accuracy: 0.8407 - 1s/epoch - 2ms/step
# Epoch 3/30
# 469/469 - 1s - loss: 0.0273 - accuracy: 0.8580 - val_loss: 0.0285 - val_accuracy: 0.8462 - 1s/epoch - 3ms/step
# Epoch 4/30
# 469/469 - 1s - loss: 0.0254 - accuracy: 0.8669 - val_loss: 0.0275 - val_accuracy: 0.8558 - 1s/epoch - 2ms/step
# Epoch 5/30
# 469/469 - 1s - loss: 0.0236 - accuracy: 0.8748 - val_loss: 0.0249 - val_accuracy: 0.8588 - 1s/epoch - 2ms/step
# Epoch 6/30
# 469/469 - 1s - loss: 0.0226 - accuracy: 0.8802 - val_loss: 0.0255 - val_accuracy: 0.8599 - 1s/epoch - 2ms/step
# Epoch 7/30
# 469/469 - 1s - loss: 0.0216 - accuracy: 0.8849 - val_loss: 0.0234 - val_accuracy: 0.8689 - 1s/epoch - 2ms/step
# Epoch 8/30
# 469/469 - 1s - loss: 0.0208 - accuracy: 0.8895 - val_loss: 0.0245 - val_accuracy: 0.8672 - 1s/epoch - 2ms/step
# Epoch 9/30
# 469/469 - 1s - loss: 0.0202 - accuracy: 0.8938 - val_loss: 0.0220 - val_accuracy: 0.8749 - 1s/epoch - 2ms/step
# Epoch 10/30
# 469/469 - 1s - loss: 0.0195 - accuracy: 0.8961 - val_loss: 0.0217 - val_accuracy: 0.8769 - 1s/epoch - 2ms/step
# Epoch 11/30
# 469/469 - 1s - loss: 0.0192 - accuracy: 0.9003 - val_loss: 0.0214 - val_accuracy: 0.8790 - 1s/epoch - 2ms/step
# Epoch 12/30
# 469/469 - 1s - loss: 0.0186 - accuracy: 0.9029 - val_loss: 0.0207 - val_accuracy: 0.8812 - 1s/epoch - 2ms/step
# Epoch 13/30
# 469/469 - 1s - loss: 0.0182 - accuracy: 0.9060 - val_loss: 0.0207 - val_accuracy: 0.8821 - 1s/epoch - 2ms/step
# Epoch 14/30
# 469/469 - 1s - loss: 0.0177 - accuracy: 0.9086 - val_loss: 0.0222 - val_accuracy: 0.8835 - 1s/epoch - 2ms/step
# Epoch 15/30
# 469/469 - 1s - loss: 0.0172 - accuracy: 0.9115 - val_loss: 0.0214 - val_accuracy: 0.8838 - 1s/epoch - 2ms/step
# Epoch 16/30
# 469/469 - 1s - loss: 0.0171 - accuracy: 0.9138 - val_loss: 0.0222 - val_accuracy: 0.8834 - 1s/epoch - 2ms/step
# Epoch 17/30
# 469/469 - 1s - loss: 0.0167 - accuracy: 0.9161 - val_loss: 0.0219 - val_accuracy: 0.8856 - 1s/epoch - 3ms/step
# Epoch 18/30
# 469/469 - 1s - loss: 0.0164 - accuracy: 0.9184 - val_loss: 0.0196 - val_accuracy: 0.8891 - 1s/epoch - 2ms/step
# Epoch 19/30
# 469/469 - 1s - loss: 0.0158 - accuracy: 0.9205 - val_loss: 0.0203 - val_accuracy: 0.8867 - 1s/epoch - 2ms/step
# Epoch 20/30
# 469/469 - 1s - loss: 0.0157 - accuracy: 0.9229 - val_loss: 0.0205 - val_accuracy: 0.8869 - 1s/epoch - 2ms/step
# Epoch 21/30
# 469/469 - 1s - loss: 0.0154 - accuracy: 0.9247 - val_loss: 0.0192 - val_accuracy: 0.8891 - 1s/epoch - 2ms/step
# Epoch 22/30
# 469/469 - 1s - loss: 0.0150 - accuracy: 0.9263 - val_loss: 0.0208 - val_accuracy: 0.8877 - 1s/epoch - 2ms/step
# Epoch 23/30
# 469/469 - 1s - loss: 0.0148 - accuracy: 0.9276 - val_loss: 0.0204 - val_accuracy: 0.8898 - 1s/epoch - 3ms/step
# Epoch 24/30
# 469/469 - 1s - loss: 0.0145 - accuracy: 0.9314 - val_loss: 0.0198 - val_accuracy: 0.8916 - 1s/epoch - 2ms/step
# Epoch 25/30
# 469/469 - 1s - loss: 0.0145 - accuracy: 0.9329 - val_loss: 0.0209 - val_accuracy: 0.8910 - 1s/epoch - 2ms/step
# Epoch 26/30
# 469/469 - 1s - loss: 0.0140 - accuracy: 0.9339 - val_loss: 0.0204 - val_accuracy: 0.8905 - 1s/epoch - 2ms/step
# Epoch 27/30
# 469/469 - 1s - loss: 0.0137 - accuracy: 0.9369 - val_loss: 0.0192 - val_accuracy: 0.8897 - 1s/epoch - 2ms/step
# Epoch 28/30
# 469/469 - 1s - loss: 0.0135 - accuracy: 0.9374 - val_loss: 0.0190 - val_accuracy: 0.8942 - 1s/epoch - 2ms/step
# Epoch 29/30
# 469/469 - 1s - loss: 0.0135 - accuracy: 0.9395 - val_loss: 0.0190 - val_accuracy: 0.8924 - 1s/epoch - 2ms/step
# Epoch 30/30
# 469/469 - 1s - loss: 0.0131 - accuracy: 0.9409 - val_loss: 0.0189 - val_accuracy: 0.8947 - 1s/epoch - 3ms/step
# 정확률은 89.46999907493591

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

#데이터 읽어와서 신경망에 입력할 형태로 변환
(x_train,y_train),(x_test, y_test)=mnist.load_data()
x_train=x_train.reshape(60000,784)
x_test = x_test.reshape(10000,784)
x_train=x_train.astype(np.float32)/255.0
x_test=x_test.astype(np.float32)/255.0
y_train=tf.keras.utils.to_categorical(y_train,10)
y_test=tf.keras.utils.to_categorical(y_test,10)

n_input=784
n_hidden1=1024
n_hidden2=512
n_hidden3=512
n_hidden4=512
n_output=10

mlp=Sequential()
mlp.add(Dense(units=n_hidden1,activation='ReLU',input_shape=(n_input,),kernel_initializer='random_uniform',bias_initializer='zeros'))
mlp.add(Dense(units=n_hidden2,activation='ReLU',kernel_initializer='random_uniform',bias_initializer='zeros'))
mlp.add(Dense(units=n_hidden3,activation='ReLU',kernel_initializer='random_uniform',bias_initializer='zeros'))
mlp.add(Dense(units=n_hidden4,activation='ReLU',kernel_initializer='random_uniform',bias_initializer='zeros'))
mlp.add(Dense(units=n_output,activation='softmax',kernel_initializer='random_uniform',bias_initializer='zeros'))

mlp.compile(loss='mean_squared_error',optimizer=Adam(learning_rate=0.001),metrics=['accuracy'])
hist=mlp.fit(x_train,y_train,batch_size=128,epochs=30,validation_data=(x_test,y_test),verbose=2)

res=mlp.evaluate(x_test,y_test,verbose=0)
print("정확률은",res[1]*100)

#정확도 곡선
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'],loc='upper left')
plt.grid()
plt.show()

#손실함수 곡선
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'],loc='upper right')
plt.grid()
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 1s 0us/step
# 11501568/11490434 [==============================] - 1s 0us/step
# Epoch 1/30
# 469/469 - 2s - loss: 0.0125 - accuracy: 0.9162 - val_loss: 0.0057 - val_accuracy: 0.9618 - 2s/epoch - 5ms/step
# Epoch 2/30
# 469/469 - 1s - loss: 0.0053 - accuracy: 0.9662 - val_loss: 0.0051 - val_accuracy: 0.9677 - 1s/epoch - 3ms/step
# Epoch 3/30
# 469/469 - 2s - loss: 0.0042 - accuracy: 0.9737 - val_loss: 0.0044 - val_accuracy: 0.9727 - 2s/epoch - 4ms/step
# Epoch 4/30
# 469/469 - 3s - loss: 0.0032 - accuracy: 0.9797 - val_loss: 0.0039 - val_accuracy: 0.9746 - 3s/epoch - 5ms/step
# Epoch 5/30
# 469/469 - 1s - loss: 0.0032 - accuracy: 0.9802 - val_loss: 0.0038 - val_accuracy: 0.9765 - 1s/epoch - 3ms/step
# Epoch 6/30
# 469/469 - 1s - loss: 0.0027 - accuracy: 0.9833 - val_loss: 0.0045 - val_accuracy: 0.9726 - 1s/epoch - 3ms/step
# Epoch 7/30
# 469/469 - 1s - loss: 0.0026 - accuracy: 0.9844 - val_loss: 0.0038 - val_accuracy: 0.9781 - 1s/epoch - 3ms/step
# Epoch 8/30
# 469/469 - 1s - loss: 0.0025 - accuracy: 0.9849 - val_loss: 0.0043 - val_accuracy: 0.9750 - 1s/epoch - 3ms/step
# Epoch 9/30
# 469/469 - 2s - loss: 0.0020 - accuracy: 0.9877 - val_loss: 0.0031 - val_accuracy: 0.9813 - 2s/epoch - 3ms/step
# Epoch 10/30
# 469/469 - 1s - loss: 0.0018 - accuracy: 0.9888 - val_loss: 0.0031 - val_accuracy: 0.9818 - 1s/epoch - 3ms/step
# Epoch 11/30
# 469/469 - 1s - loss: 0.0020 - accuracy: 0.9882 - val_loss: 0.0045 - val_accuracy: 0.9730 - 1s/epoch - 3ms/step
# Epoch 12/30
# 469/469 - 1s - loss: 0.0020 - accuracy: 0.9880 - val_loss: 0.0035 - val_accuracy: 0.9795 - 1s/epoch - 3ms/step
# Epoch 13/30
# 469/469 - 1s - loss: 0.0017 - accuracy: 0.9900 - val_loss: 0.0034 - val_accuracy: 0.9786 - 1s/epoch - 3ms/step
# Epoch 14/30
# 469/469 - 1s - loss: 0.0018 - accuracy: 0.9898 - val_loss: 0.0044 - val_accuracy: 0.9746 - 1s/epoch - 3ms/step
# Epoch 15/30
# 469/469 - 2s - loss: 0.0016 - accuracy: 0.9904 - val_loss: 0.0035 - val_accuracy: 0.9801 - 2s/epoch - 3ms/step
# Epoch 16/30
# 469/469 - 2s - loss: 0.0012 - accuracy: 0.9927 - val_loss: 0.0037 - val_accuracy: 0.9781 - 2s/epoch - 3ms/step
# Epoch 17/30
# 469/469 - 1s - loss: 0.0015 - accuracy: 0.9912 - val_loss: 0.0055 - val_accuracy: 0.9677 - 1s/epoch - 3ms/step
# Epoch 18/30
# 469/469 - 2s - loss: 0.0015 - accuracy: 0.9912 - val_loss: 0.0032 - val_accuracy: 0.9812 - 2s/epoch - 3ms/step
# Epoch 19/30
# 469/469 - 2s - loss: 0.0015 - accuracy: 0.9913 - val_loss: 0.0043 - val_accuracy: 0.9751 - 2s/epoch - 3ms/step
# Epoch 20/30
# 469/469 - 1s - loss: 0.0012 - accuracy: 0.9934 - val_loss: 0.0032 - val_accuracy: 0.9818 - 1s/epoch - 3ms/step
# Epoch 21/30
# 469/469 - 1s - loss: 0.0013 - accuracy: 0.9930 - val_loss: 0.0034 - val_accuracy: 0.9805 - 1s/epoch - 3ms/step
# Epoch 22/30
# 469/469 - 1s - loss: 0.0012 - accuracy: 0.9932 - val_loss: 0.0040 - val_accuracy: 0.9773 - 1s/epoch - 3ms/step
# Epoch 23/30
# 469/469 - 1s - loss: 0.0013 - accuracy: 0.9924 - val_loss: 0.0037 - val_accuracy: 0.9792 - 1s/epoch - 3ms/step
# Epoch 24/30
# 469/469 - 1s - loss: 0.0015 - accuracy: 0.9916 - val_loss: 0.0037 - val_accuracy: 0.9790 - 1s/epoch - 3ms/step
# Epoch 25/30
# 469/469 - 2s - loss: 0.0010 - accuracy: 0.9939 - val_loss: 0.0039 - val_accuracy: 0.9774 - 2s/epoch - 3ms/step
# Epoch 26/30
# 469/469 - 1s - loss: 0.0012 - accuracy: 0.9930 - val_loss: 0.0035 - val_accuracy: 0.9798 - 1s/epoch - 3ms/step
# Epoch 27/30
# 469/469 - 1s - loss: 0.0012 - accuracy: 0.9933 - val_loss: 0.0035 - val_accuracy: 0.9801 - 1s/epoch - 3ms/step
# Epoch 28/30
# 469/469 - 1s - loss: 0.0012 - accuracy: 0.9933 - val_loss: 0.0034 - val_accuracy: 0.9809 - 1s/epoch - 3ms/step
# Epoch 29/30
# 469/469 - 1s - loss: 0.0013 - accuracy: 0.9925 - val_loss: 0.0038 - val_accuracy: 0.9792 - 1s/epoch - 3ms/step
# Epoch 30/30
# 469/469 - 1s - loss: 0.0012 - accuracy: 0.9931 - val_loss: 0.0031 - val_accuracy: 0.9830 - 1s/epoch - 3ms/step
# 정확률은 98.29999804496765
